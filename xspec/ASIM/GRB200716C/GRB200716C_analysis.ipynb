# %%
import os
path = os.getcwd()

if path[1:5] == 'Home':
    # %run /Home/siv30/wad005/master/GRB/src/harvest_matlab_data.ipynb
    # %run /Home/siv30/wad005/master/GRB/src/background_rates.ipynb
    # %run /Home/siv30/wad005/master/GRB/src/dau_det_distribution.ipynb
else:
    # %run /Users/andreas/phys/master/GRB/src/harvest_matlab_data.ipynb
    # %run /Users/andreas/phys/master/GRB/src/background_rates.ipynb
    # %run /Users/andreas/phys/master/GRB/src/dau_det_distribution.ipynb
# Out:
# all UiB paths loaded
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
# convert_erg.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
# convert_erg.ipynb loaded successfully!
# safety_time.ipynb loaded successfully!
#
# all UiB paths loaded
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
# convert_erg.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
#
# all UiB paths loaded
# read_matlab_file.ipynb loaded successfully!
# convert_erg.ipynb loaded successfully!
# safety_time.ipynb loaded successfully!
# LC_calibration loaded successfully!

# %%
t_start = datetime.now()
df_harvest = harvest_data(fn='2020_7_16_22_57_40',T0='2020-07-16T22:57:40.634')
t_end = datetime.now()
print((t_end-t_start).total_seconds())
# Out:
# dau/det starting from index 1
# tus array given in seconds
# safety time:  0.178 % removed
# tus given in seconds
# 1.881521

# %%
plot_HED(tus_arr=df_harvest['tus'].to_numpy()*1e6,binsize=64,T0=datetime.fromisoformat('2020-07-16T22:57:40.634'))
# Out:
# tus array OK ...

# %%
cr,df_cr = get_count_rate(fn='2020_7_16_22_57_40',T0='2020-07-16T22:57:40.634',bkg_start='start',bkg_end=-32)
# Out:
# 2020-07-16 22:57:40.634000
# bkg starts and ends at:  start -32 s
# dau/det starting from index 1
# tus array given in seconds
# safety time:  0.178 % removed
# tus given in seconds
# background count rate:  4762.875  counts/s
# returning count_rate and background df (sorted by tus (s) and st removed)

# %%
df_cr
# Out:
#       year  month  day  hour  minute    second   erg dau det  \
# 0     2020      7   16    22      57  4.835626   577   3   3
# 1     2020      7   16    22      57  4.835834    39   2   2
# 2     2020      7   16    22      57  4.835857  1604   2   2
# 3     2020      7   16    22      57  4.835947  2156   1   3
# 4     2020      7   16    22      57  4.835947  1546   2   1
# ...    ...    ...  ...   ...     ...       ...   ...  ..  ..
# 9567  2020      7   16    22      57  6.844235  1642   2   2
# 9568  2020      7   16    22      57  6.844858  1569   3   1
# 9569  2020      7   16    22      57  6.845163    95   4   3
# 9570  2020      7   16    22      57  6.845163    22   3   1
# 9571  2020      7   16    22      57  6.845336   125   1   2
#
#                           datetime        tus  adr           keV         st  \
# 0    2020-07-16 22:57:04.835625667 -35.798374    9  13128.056274  17.000000
# 1    2020-07-16 22:57:04.835833778 -35.798166    5    508.365720   1.050194
# 2    2020-07-16 22:57:04.835856972 -35.798143    5  29709.794620  23.000000
# 3    2020-07-16 22:57:04.835947167 -35.798053    3  36372.689512  26.647227
# 4    2020-07-16 22:57:04.835947222 -35.798053    4  26036.494246  23.000000
# ...                            ...        ...  ...           ...        ...
# 9567 2020-07-16 22:57:06.844234639 -33.789765    5  30663.713180  23.265485
# 9568 2020-07-16 22:57:06.844858333 -33.789142    7  29718.895707  19.000000
# 9569 2020-07-16 22:57:06.845163194 -33.788837   12   1290.651200   2.968837
# 9570 2020-07-16 22:57:06.845163306 -33.788837    7    513.474098   1.000000
# 9571 2020-07-16 22:57:06.845336194 -33.788664    2   2758.137800   3.000000
#
#             dt   flag
# 0        0.000  False
# 1        0.000  False
# 2       23.194  False
# 3        0.000  False
# 4        0.000  False
# ...        ...    ...
# 9567  3462.528  False
# 9568  1800.555  False
# 9569  2091.805  False
# 9570   304.973  False
# 9571  6496.694  False
#
# [9572 rows x 16 columns]
